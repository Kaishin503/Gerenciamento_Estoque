# %%
#Base Do CRUD Organizada Em Funções Com Tratamento Básico De Erros.

# %%
import psycopg
conn = psycopg.connect(
    dbname = "bancodedados",
    user = "postgres",
    password = "22082008jp",
    host = "localhost",
    port = 5432
)
cursor = conn.cursor()

# %%
print("Bem Vindo(a)! Abaixo Estão As Funções E Seus Respectivos Números")
print("----------------------------------------------------------------")
print("1 - Cadastrar Produto | 2 - Cadastrar Categoria | 3 - Listar Produtos ")
print("4 - Buscar Produto | 5 - Deletar Produto | 6 - Atualizar Produto  ")
print("7 - Registrar Entrada E Saída ")


while True:
    while True:
        try:
            opcao = int(input("Digite A Função Desejada:"))
            break
        except ValueError:
            print("Digite Um Número Válido!")
            continue
    if opcao == 1:
        from CRUDFUNCTIONS import Cadastro
        Cadastro(conn,cursor)
    elif opcao == 2:
        from CRUDFUNCTIONS import Cadastro_Categoria
        Cadastro_Categoria(cursor)
    elif opcao == 3:
        from CRUDFUNCTIONS import Listagem
        Listagem(cursor)
    elif opcao == 4:
        from CRUDFUNCTIONS import Busca
        Busca(cursor)
    elif opcao == 5:
       from CRUDFUNCTIONS import Deletar
       Deletar(conn,cursor)
    elif opcao == 6:
        from CRUDFUNCTIONS import Atualizar
        Atualizar(conn,cursor)
    elif opcao == 0:
        print("Saindo...")
        break
# Out:
# Bem Vindo(a)! Abaixo Estão As Funções E Seus Respectivos Números
# ----------------------------------------------------------------
# 1 - Cadastrar Produto | 2 - Cadastrar Categoria | 3 - Listar Produtos
# 4 - Buscar Produto | 5 - Deletar Produto | 6 - Atualizar Produto
# 7 - Registrar Entrada E Saída
# SISTEMA: Nome Validado!
# SISTEMA: Categoria Encontrada!
# SISTEMA: Preço Validado!
# SISTEMA: Quantidade Validada!
# ID:5
# Nome: banana
# Categoria: fruta
# Chave Da Categoria: 2
# Preço: R$3.99
# Quantidade: 100 Unidades
#
# ID:6
# Nome: maçã
# Categoria: fruta
# Chave Da Categoria: 1
# Preço: R$5.99
# Quantidade: 240 Unidades
#
# Saindo...
